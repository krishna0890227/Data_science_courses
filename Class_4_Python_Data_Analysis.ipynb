# %% [markdown]
# # Python Data Analysis

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %%
Temp= [10, 14, 15, 17, 17, 39, 30, 40]
time =[10, 11, 12, 13, 14, 15, 16, 18]
import matplotlib.pyplot as plt
plt.plot(time, Temp)
plt.xlabel('Time')
plt.ylabel('Values')
plt.title('Temperature inside the crop Building')
plt.show()

# %%
import numpy as np
Temp1= np.array(Temp)
Temp2= Temp1*2
print(Temp2)
# Out:
# [20 28 30 34 34 78 60 80]

# %%
Temp2[1:5]
# Out:
# array([28, 30, 34, 34])

# %%
Temp3= Temp*2
print(Temp3)
# Out:
# [10, 14, 15, 17, 17, 39, 30, 40, 10, 14, 15, 17, 17, 39, 30, 40]

# %%
Temp= [[1, 5, 8], [4, 9, 4], [6, 9, 6]]

# %%
Temp1=np.array(Temp)
print(Temp1)
print(Temp1.shape)
# Out:
# [[1 5 8]
#  [4 9 4]
#  [6 9 6]]
# (3, 3)

# %%
import pandas as pd

data= pd.read_excel('Humidity_Temp.xlsx')

# %%
data.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN         NaN                  NaN        NaN        NaN
# 1         NaN         NaN                  NaN        NaN        NaN
# 2         NaN         NaN                  NaN        NaN        NaN
# 3         NaN         NaN                 Date   Temp_MAX   Temp_MIN
# 4         NaN         NaN  2024-04-02 00:00:00       30.2       19.8
# 5         NaN         NaN  2024-04-03 00:00:00         31       13.1
# 6         NaN         NaN  2024-04-04 00:00:00       37.6         13
# 7         NaN         NaN  2024-04-05 00:00:00       38.3       13.5
# 8         NaN         NaN  2024-04-06 00:00:00       37.9       12.8
# 9         NaN         NaN  2024-04-07 00:00:00       39.4         12
#
#   Unnamed: 5 Unnamed: 6
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3    Hum_MAX    Hum_MIN
# 4         66         42
# 5         92         46
# 6         95         20
# ...

# %%
data = data.iloc[3:, 2:]
data.head(10)
# Out:
#              Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 3                  Date   Temp_MAX   Temp_MIN    Hum_MAX    Hum_MIN
# 4   2024-04-02 00:00:00       30.2       19.8         66         42
# 5   2024-04-03 00:00:00         31       13.1         92         46
# 6   2024-04-04 00:00:00       37.6         13         95         20
# 7   2024-04-05 00:00:00       38.3       13.5         96         20
# 8   2024-04-06 00:00:00       37.9       12.8         95         20
# 9   2024-04-07 00:00:00       39.4         12         96         20
# 10  2024-04-08 00:00:00       37.7       10.7         94         20
# 11  2024-04-09 00:00:00       35.5        9.3         95         20
# 12  2024-04-10 00:00:00         36         11         94         20

# %%
data.columns = data.iloc[0]

# %%
data.head()
# Out:
# 3                 Date  Temp_MAX  Temp_MIN  Hum_MAX  Hum_MIN
# 3                 Date  Temp_MAX  Temp_MIN  Hum_MAX  Hum_MIN
# 4  2024-04-02 00:00:00      30.2      19.8       66       42
# 5  2024-04-03 00:00:00        31      13.1       92       46
# 6  2024-04-04 00:00:00      37.6        13       95       20
# 7  2024-04-05 00:00:00      38.3      13.5       96       20

# %%
data= data.iloc[1:,:]

# %%
data.head()
# Out:
# 3                 Date Temp_MAX Temp_MIN Hum_MAX Hum_MIN
# 4  2024-04-02 00:00:00     30.2     19.8      66      42
# 5  2024-04-03 00:00:00       31     13.1      92      46
# 6  2024-04-04 00:00:00     37.6       13      95      20
# 7  2024-04-05 00:00:00     38.3     13.5      96      20
# 8  2024-04-06 00:00:00     37.9     12.8      95      20

# %%
data.describe()
# Out:
# 3                      Date  Temp_MAX  Temp_MIN  Hum_MAX  Hum_MIN
# count                    50      50.0      50.0       50       50
# unique                   50      39.0      37.0       10       17
# top     2024-04-02 00:00:00      37.0      12.0       99       20
# freq                      1       4.0       4.0       14       22

# %%
print(data.dtypes)
print("========================")
print(data.columns)
print("========================")
print(data.ndim)
print("========================")
print(data.size)
print("========================")
print(data.shape)
print("========================")
print(data.values)
# Out:
# 3
# Date        object
# Temp_MAX    object
# Temp_MIN    object
# Hum_MAX     object
# Hum_MIN     object
# dtype: object
# ...
# Index(['Date', 'Temp_MAX', 'Temp_MIN', 'Hum_MAX', 'Hum_MIN'], dtype='object', name=3)
# ...
# 2
# ...
# 250
# ...
# (50, 5)
# ...
# [[datetime.datetime(2024, 4, 2, 0, 0) 30.2 19.8 66 42]
#  [datetime.datetime(2024, 4, 3, 0, 0) 31 13.1 92 46]
#  [datetime.datetime(2024, 4, 4, 0, 0) 37.6 13 95 20]
#  [datetime.datetime(2024, 4, 5, 0, 0) 38.3 13.5 96 20]
#  [datetime.datetime(2024, 4, 6, 0, 0) 37.9 12.8 95 20]
#  [datetime.datetime(2024, 4, 7, 0, 0) 39.4 12 96 20]
#  [datetime.datetime(2024, 4, 8, 0, 0) 37.7 10.7 94 20]
#  [datetime.datetime(2024, 4, 9, 0, 0) 35.5 9.3 95 20]
#  [datetime.datetime(2024, 4, 10, 0, 0) 36 11 94 20]
#  [datetime.datetime(2024, 4, 11, 0, 0) 33.9 10.2 94 22]
#  [datetime.datetime(2024, 4, 12, 0, 0) 34.4 12.4 99 30]
#  [datetime.datetime(2024, 4, 13, 0, 0) 35 12 95 20]
#  [datetime.datetime(2024, 4, 14, 0, 0) 36.5 14.3 94 22]
# ...

# %%
data.describe()
# Out:
# 3                      Date  Temp_MAX  Temp_MIN  Hum_MAX  Hum_MIN
# count                    50      50.0      50.0       50       50
# unique                   50      39.0      37.0       10       17
# top     2024-04-02 00:00:00      37.0      12.0       99       20
# freq                      1       4.0       4.0       14       22

# %%
data.to_csv("temp_humidity.csv")

# %%
temp_max = data[["Temp_MAX", "Temp_MIN"]].values
temp_max1 =data.Temp_MAX
print(temp_max)
print(temp_max1)
# Out:
# [[30.2 19.8]
#  [31 13.1]
#  [37.6 13]
#  [38.3 13.5]
#  [37.9 12.8]
#  [39.4 12]
#  [37.7 10.7]
#  [35.5 9.3]
#  [36 11]
#  [33.9 10.2]
#  [34.4 12.4]
#  [35 12]
#  [36.5 14.3]
#  [37.8 15.7]
#  [38.5 16.1]
#  [37.7 15.2]
#  [37 15.7]
#  [37.1 16.3]
#  [38.1 16]
#  [38.6 16]
#  [39.8 13.3]
#  [38.2 12.5]
#  [38.5 12]
#  [37.8 13]
#  [37 13.3]
#  [37.3 13.5]
#  [39.6 14]
#  [39 12.9]
#  [40.4 12.7]
#  [37.5 9.5]
#  [37.5 10.2]
#  [37.5 10.5]
#  [37 12]
#  [36.8 12.4]
#  [35.4 14]
#  [31.5 15.5]
#  [25.5 16.7]
#  [35.3 16.7]
#  [37 16]
#  [31.8 11.7]
#  [26.5 20.4]
#  [34.7 17.1]
#  [38.1 17.7]
#  [39.4 19.7]
#  [38.8 18]
#  [38.8 16.5]
#  [37.4 17.2]
#  [36.1 18.9]
#  [30.1 18.8]
#  [38.7 19]]
# 4     30.2
# 5       31
# 6     37.6
# 7     38.3
# 8     37.9
# 9     39.4
# 10    37.7
# 11    35.5
# 12      36
# 13    33.9
# 14    34.4
# 15      35
# 16    36.5
# 17    37.8
# 18    38.5
# 19    37.7
# 20      37
# 21    37.1
# 22    38.1
# 23    38.6
# 24    39.8
# 25    38.2
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(temp_max)
plt.title("Maximum temperature")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(temp_min)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(temp_max, 'r-')
plt.plot(temp_min, 'k-*')
plt.show()
